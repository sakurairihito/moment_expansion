# %%
using Plots
using QuadGK
using LinearAlgebra

# %%
aomega(omega) = 1/3 * ( exp(-0.5 * (omega/0.5)^2)/sqrt(2*π*0.5^2) + exp(-0.5 * (omega+5)^2)/sqrt(2*π) + exp(-0.5 * (omega-5)^2)/sqrt(2*π))
# Out:
# aomega (generic function with 1 method)

# %%
wmax = 15
omegas = LinRange(-wmax, wmax, 1000)
plot(omegas, aomega.(omegas))

# %%
c = quadgk(x -> aomega(x), -wmax, wmax)[1]
println("normalize=", quadgk(x -> aomega(x), -wmax, wmax)[1])
# Out:
# normalize=0.9999999999999155

# %% [markdown]
# # particle

# %% [markdown]
# $$
# T^{(n)}_p = (-1)^{n+1} \frac{d^n G(\tau)}{d\tau^n} \mid_{\tau=0^+}
# $$
#
# $$
# T^{(n)}_h = (-1)^{n} \frac{d^n G(\tau)}{d\tau^n} \mid_{\tau=0^+}
# $$
#
# $$
# S_n = T[0]^{-1/2} T[n] T[0]^{-1/2}
# $$

# %%
nmom = 20
Tp = Float64[]
for mom in 0:(nmom-1)
    push!(Tp, quadgk(x -> (x^mom) * aomega(x), 0, wmax)[1])
end
Tp
# Out:
# 20-element Vector{Float64}:
#       0.5
#       1.733157082374676
#       8.708333333333334
#      46.69991186350469
#     259.3645833333333
#    1483.366578527266
#    8713.372395833318
#   52466.71653445595
#  323326.73502604157
#       2.036366766402243e6
#       1.3091773487141926e7
#       8.582253358267228e7
#       5.731221737563069e8
#       3.8954812674146833e9
#       2.6927994588041332e10
#       1.8917671066928473e11
#       1.3498034721384883e12
#       9.775844731343807e12
#       7.182588268295523e13
#       5.350946185787138e14

# %%
function reconst(T)
    nmom = length(T)
    S = (1/sqrt(T[1])) * T * (1/sqrt(T[1]))
    println(S)

    As = Dict{Int,ComplexF64}()
    Bs = Dict{Int,ComplexF64}()
    Cs = Dict{Tuple{Int,Int},ComplexF64}()

    # Initial values
    As[0] = S[2]
    Bs[0] = 0.0
    Cs[0,0] = 1.0

    function get_S(i)
        i <= nmom-1 ? S[i+1] : 0.0
    end
    
    function get_Cs(n, j)::ComplexF64
        if j < 0 || j > n || n < 0
            return 0.0
        end
        return Cs[(n, j)]
    end

    for n in 0:nmom
        #println("n = $n")
        # Update B[n+1]
        bfirst = sum(conj(Cs[n,l]) * get_S(j+l+1) * get_Cs(n, j-1) for j in 0:(n+1), l in 0:n)
        Bs[n+1] = sqrt(bfirst  - As[n]^2  - conj(Bs[n]^2))

        # C(n+1, j) for j = 0, ..., n+1 (otherwise 0)
        for j in 0:(n+1)
            Cs[(n+1, j)] = (get_Cs(n, j-1) - get_Cs(n, j) * As[n] - get_Cs(n-1, j) * conj(Bs[n])) / Bs[n+1]
        end

        # Update A[n+1]
        As[n+1] = sum(conj(get_Cs(n+1, l) * get_S(j+l+1) * get_Cs(n+1, j)) for j in 0:(n+1), l in 0:(n+1))

        if length(As) >= (nmom + 1) ÷ 2
            break
        end
    end
    return  As, Bs
end

As, Bs = reconst(Tp)
# Out:
# [0.9999999999999998, 3.4663141647493516, 17.416666666666664, 93.39982372700936, 518.7291666666665, 2966.733157054531, 17426.74479166663, 104933.43306891188, 646653.470052083, 4.0727335328044854e6, 2.6183546974283848e7, 1.7164506716534454e8, 1.1462443475126135e9, 7.790962534829365e9, 5.385598917608265e10, 3.783534213385694e11, 2.699606944276976e12, 1.955168946268761e13, 1.4365176536591044e14, 1.0701892371574275e15]
# (Dict{Int64, ComplexF64}(0 => 3.4663141647493516 + 0.0im, 4 => 3.9287656754204363 + 0.0im, 5 => 5.160283867648104 + 0.0im, 6 => 5.123313153395429 + 0.0im, 2 => 4.8907013965832675 + 0.0im, 7 => 4.736030776053667 + 0.0im, 9 => 5.764146685600281 + 0.0im, 8 => 5.306875616312027 + 0.0im, 3 => 4.109381925398793 + 0.0im, 1 => 2.6485072535145893 + 0.0im…), Dict{Int64, ComplexF64}(0 => 0.0 + 0.0im, 4 => 2.5120246329603217 + 0.0im, 5 => 2.2450930343439173 + 0.0im, 6 => 2.161777429728777 + 0.0im, 2 => 1.576689008578524 + 0.0im, 7 => 2.5941315150277884 + 0.0im, 9 => 2.5851608009840974 + 0.0im, 8 => 2.7428931608441944 + 0.0im, 3 => 1.6969800614244384 + 0.0im, 1 => 2.324076758182627 + 0.0im…))

# %%
nc = length(As)
htri = zeros(ComplexF64, nc, nc)
for i in 1:nc
    htri[i, i] = As[i-1]
end
for i in 1:(nc-1)
    htri[i, i+1] = Bs[i]
    htri[i+1, i] = conj(Bs[i])
end

htri
# Out:
# 10×10 Matrix{ComplexF64}:
#  3.46631+0.0im  2.32408+0.0im      0.0+0.0im  …      0.0+0.0im      0.0+0.0im
#  2.32408-0.0im  2.64851+0.0im  1.57669+0.0im         0.0+0.0im      0.0+0.0im
#      0.0+0.0im  1.57669-0.0im   4.8907+0.0im         0.0+0.0im      0.0+0.0im
#      0.0+0.0im      0.0+0.0im  1.69698-0.0im         0.0+0.0im      0.0+0.0im
#      0.0+0.0im      0.0+0.0im      0.0+0.0im         0.0+0.0im      0.0+0.0im
#      0.0+0.0im      0.0+0.0im      0.0+0.0im  …      0.0+0.0im      0.0+0.0im
#      0.0+0.0im      0.0+0.0im      0.0+0.0im         0.0+0.0im      0.0+0.0im
#      0.0+0.0im      0.0+0.0im      0.0+0.0im     2.74289+0.0im      0.0+0.0im
#      0.0+0.0im      0.0+0.0im      0.0+0.0im     5.30688+0.0im  2.58516+0.0im
#      0.0+0.0im      0.0+0.0im      0.0+0.0im     2.58516-0.0im  5.76415+0.0im

# %%
e = eigen(Hermitian(htri))
# Out:
# Eigen{ComplexF64, Float64, Matrix{ComplexF64}, Vector{Float64}}
# values:
# 10-element Vector{Float64}:
#  0.08629687764005334
#  0.422261922286585
#  0.9807229523130909
#  2.932979508240211
#  4.088022939738118
#  5.145948288224045
#  6.183683056537393
#  7.243051904234397
#  8.372869418782962
#  9.678483646679075
# vectors:
# 10×10 Matrix{ComplexF64}:
#  -0.336905-0.0im   -0.407143-0.0im  …   0.0327365-0.0im  0.00263456-0.0im
#   0.489978+0.0im    0.533272+0.0im      0.0691129-0.0im  0.00704207-0.0im
#  -0.299636-0.0im   -0.152828-0.0im       0.202668-0.0im   0.0275151-0.0im
#   0.393068+0.0im  -0.0930483-0.0im       0.351657-0.0im   0.0710869-0.0im
#  -0.427093-0.0im    0.239817+0.0im       0.459933-0.0im     0.13901-0.0im
#   0.291167+0.0im   -0.270447-0.0im  …    0.516958+0.0im    0.276469-0.0im
#  -0.239855-0.0im    0.343687+0.0im       0.290584-0.0im    0.433463-0.0im
#   0.223087+0.0im   -0.397452-0.0im     -0.0667962-0.0im    0.530749-0.0im
#  -0.151329-0.0im    0.300029+0.0im       -0.36339-0.0im     0.54641+0.0im
#  0.0689009+0.0im   -0.145196-0.0im      -0.360108-0.0im    0.360868-0.0im

# %%
weight = real.(conj.(e.vectors[1, :]) .* e.vectors[1, :])
# Out:
# 10-element Vector{Float64}:
#  0.1135051361017624
#  0.16576536834974234
#  0.054605523841336004
#  0.03990077783512052
#  0.19061577110028347
#  0.2736915280743591
#  0.13753044065531914
#  0.023306831999319575
#  0.0010716811458697244
#  6.940896887466331e-6

# %%
sum(weight)
# Out:
# 0.9999999999999998

# %%
δ = 0.2
#p = 0.25
gaussian(x, μ) = exp(-0.5 * ((x-μ)/δ)^2)/(sqrt(2π * δ^2))

cp = quadgk(x -> aomega(x), 0, wmax)[1]
aomega_reconst = zeros(Float64, length(omegas))
for ie in eachindex(e.values)
    aomega_reconst .+= 0.5 * gaussian.(omegas, e.values[ie]) * weight[ie]
end

p = plot(xlim=(-wmax, wmax))
plot!(p, omegas, (aomega_reconst), xlim=(-wmax, wmax), marker=:x)
plot!(p, omegas, aomega.(omegas))

# %% [markdown]
# # hole

# %%
Th = Float64[]
for mom in 0:(nmom-1)
    push!(Th, quadgk(x -> (x^mom) * aomega(x), -wmax, 0)[1])
end
Th
# Out:
# 20-element Vector{Float64}:
#       0.5
#      -1.733157082374676
#       8.708333333333332
#     -46.69991186350468
#     259.3645833333333
#   -1483.366578527266
#    8713.372395833318
#  -52466.71653445595
#  323326.7350260416
#      -2.0363667664022427e6
#       1.3091773487141926e7
#      -8.582253358267228e7
#       5.731221737563069e8
#      -3.895481267414684e9
#       2.6927994588041336e10
#      -1.8917671066928473e11
#       1.3498034721384885e12
#      -9.775844731343807e12
#       7.182588268295523e13
#      -5.350946185787138e14

# %%
Ash, Bsh = reconst(Th)
# Out:
# [0.9999999999999998, -3.4663141647493516, 17.41666666666666, -93.39982372700933, 518.7291666666665, -2966.733157054531, 17426.74479166663, -104933.43306891188, 646653.4700520831, -4.0727335328044845e6, 2.6183546974283848e7, -1.7164506716534454e8, 1.1462443475126135e9, -7.790962534829367e9, 5.3855989176082664e10, -3.783534213385694e11, 2.6996069442769766e12, -1.955168946268761e13, 1.4365176536591044e14, -1.0701892371574275e15]
# (Dict{Int64, ComplexF64}(0 => -3.4663141647493516 + 0.0im, 4 => -3.9287656753731426 + 0.0im, 5 => -5.160283865669044 + 0.0im, 6 => -5.123313111020252 + 0.0im, 2 => -4.890701396583211 + 0.0im, 7 => -4.736030377447605 + 0.0im, 9 => -5.764097571372986 + 0.0im, 8 => -5.306870564818382 + 0.0im, 3 => -4.109381925397429 + 0.0im, 1 => -2.6485072535145893 + 0.0im…), Dict{Int64, ComplexF64}(0 => 0.0 + 0.0im, 4 => 2.5120246329623566 + 0.0im, 5 => 2.24509303453783 + 0.0im, 6 => 2.1617774352747006 + 0.0im, 2 => 1.57668900857853 + 0.0im, 7 => 2.594131573272923 + 0.0im, 9 => 2.5851676342225813 + 0.0im, 8 => 2.7428937125234976 + 0.0im, 3 => 1.6969800614247301 + 0.0im, 1 => 2.3240767581826263 + 0.0im…))

# %%
nch = length(Ash)
htrih = zeros(ComplexF64, nc, nc)
for i in 1:nch
    htrih[i, i] = Ash[i-1]
end
for i in 1:(nch-1)
    htrih[i, i+1] = Bsh[i]
    htrih[i+1, i] = conj(Bsh[i])
end

htrih
# Out:
# 10×10 Matrix{ComplexF64}:
#  -3.46631+0.0im   2.32408+0.0im  …       0.0+0.0im      0.0+0.0im
#   2.32408-0.0im  -2.64851+0.0im          0.0+0.0im      0.0+0.0im
#       0.0+0.0im   1.57669-0.0im          0.0+0.0im      0.0+0.0im
#       0.0+0.0im       0.0+0.0im          0.0+0.0im      0.0+0.0im
#       0.0+0.0im       0.0+0.0im          0.0+0.0im      0.0+0.0im
#       0.0+0.0im       0.0+0.0im  …       0.0+0.0im      0.0+0.0im
#       0.0+0.0im       0.0+0.0im          0.0+0.0im      0.0+0.0im
#       0.0+0.0im       0.0+0.0im      2.74289+0.0im      0.0+0.0im
#       0.0+0.0im       0.0+0.0im     -5.30687+0.0im  2.58517+0.0im
#       0.0+0.0im       0.0+0.0im      2.58517-0.0im  -5.7641+0.0im

# %%
eh = eigen(Hermitian(htrih))
# Out:
# Eigen{ComplexF64, Float64, Matrix{ComplexF64}, Vector{Float64}}
# values:
# 10-element Vector{Float64}:
#  -9.67847866512395
#  -8.372864191521911
#  -7.243046298395602
#  -6.183676937603919
#  -5.1459414729874275
#  -4.088015087889686
#  -2.9329693289582086
#  -0.9807179838415787
#  -0.4222596200917663
#  -0.08629631953193358
# vectors:
# 10×10 Matrix{ComplexF64}:
#   0.00263459+0.0im  -0.0327368-0.0im  …    0.407143-0.0im   0.336904-0.0im
#  -0.00704215-0.0im   0.0691134+0.0im       0.533272+0.0im   0.489976+0.0im
#    0.0275153+0.0im    -0.20267-0.0im       0.152829-0.0im   0.299635-0.0im
#   -0.0710875-0.0im    0.351659+0.0im     -0.0930448-0.0im   0.393067-0.0im
#     0.139011+0.0im   -0.459934-0.0im      -0.239813-0.0im   0.427093-0.0im
#    -0.276471-0.0im    0.516957+0.0im  …   -0.270445-0.0im   0.291168-0.0im
#     0.433465+0.0im   -0.290581-0.0im      -0.343686-0.0im   0.239857-0.0im
#     -0.53075-0.0im  -0.0668005-0.0im      -0.397453-0.0im   0.223089-0.0im
#     0.546409+0.0im    0.363392+0.0im      -0.300031-0.0im   0.151331-0.0im
#    -0.360864-0.0im   -0.360105-0.0im      -0.145199-0.0im  0.0689027-0.0im

# %%
weighth = real.(conj.(eh.vectors[1, :]) .* eh.vectors[1, :])
# Out:
# 10-element Vector{Float64}:
#  6.941059426660753e-6
#  0.0010717003251882367
#  0.02330713456313814
#  0.13753151488172982
#  0.27369201674924465
#  0.1906146416040289
#  0.039900084363854164
#  0.0546062449361111
#  0.1657652579983982
#  0.11350446351888031

# %%
sum(weighth)
# Out:
# 1.0

# %%
#hole
#δ = 0.2
gaussianh(x, μh) = exp(-0.5 * ((x-μh)/δ)^2)/(sqrt(2π * δ^2))

#hole
ch = quadgk(x -> aomega(x), -wmax, 0)[1]
println("ch=", ch)
aomega_reconsth = zeros(Float64, length(omegas))
for ieh in eachindex(eh.values)
    aomega_reconsth .+= 0.5 * gaussianh.(omegas, eh.values[ieh]) * weighth[ieh]
end


p = plot(xlim=(-wmax, wmax))
plot!(p, omegas, aomega.(omegas))
plot!(p, omegas, (aomega_reconsth), xlim=(-wmax, wmax), marker=:x)
# Out:
# ch=0.5

# %% [markdown]
# # whole picture

# %%
aomega_reconst_all = (aomega_reconst + aomega_reconsth)
#println(aomega_reconst_all)
p = plot(xlim=(-wmax, wmax))
plot!(p, omegas, aomega.(omegas))
plot!(p, omegas, (aomega_reconst_all), xlim=(-wmax, wmax), marker=:x)
#plot!(p, omegas, (aomega_reconsth),  xlim=(-wmax, wmax), maker=:x)

# %%
savefig("nmom=$(nmom), δ=$()")
