# %%
using Plots
using QuadGK
using LinearAlgebra

# %% [markdown]
# $$
# f(x)=\frac{1}{\sqrt{2 \pi \sigma^{2}}} \exp \left(-\frac{(x-\mu)^{2}}{2 \sigma^{2}}\right) \quad(x \in \mathbb{R})
# $$

# %%
aomega(omega) = 1/3 * ( exp(-0.5 * (omega/0.1)^2)/sqrt(2*π*0.1^2) + exp(-0.5 * (omega+5)^2)/sqrt(2*π) + exp(-0.5 * (omega-5)^2)/sqrt(2*π))
# Out:
# aomega (generic function with 1 method)

# %%
wmax = 13
omegas = LinRange(-wmax, wmax, 1000)
plot(omegas, aomega.(omegas))

# %%
c = quadgk(x -> aomega(x), -wmax, wmax)[1]
println("normalize=", quadgk(x -> aomega(x), -wmax, wmax)[1])
# Out:
# normalize=0.9999999999999997

# %% [markdown]
# # particle

# %% [markdown]
# $$
# T^{(n)}_p = (-1)^{n+1} \frac{d^n G(\tau)}{d\tau^n} \mid_{\tau=0^+}
# $$
#
# $$
# T^{(n)}_h = (-1)^{n} \frac{d^n G(\tau)}{d\tau^n} \mid_{\tau=0^+}
# $$
#
# $$
# S_n = T[0]^{-1/2} T[n] T[0]^{-1/2}
# $$

# %%
nmom = 17
Tp = Float64[]
for mom in 0:(nmom-1)
    push!(Tp, quadgk(x -> (x^mom) * aomega(x), 0, wmax)[1])
end
Tp
# Out:
# 17-element Vector{Float64}:
#       0.4999999999999998
#       1.6799647783211487
#       8.6683333333333
#      46.66693263499102
#     259.3333833333407
#    1483.3333446725562
#    8713.333335887768
#   52466.66666726336
#  323326.6666666376
#       2.0363666666643184e6
#       1.3091773333301853e7
#       8.582253333291975e7
#       5.731221733279006e8
#       3.8954812665953045e9
#       2.692799458572916e10
#       1.8917671065434918e11
#       1.3498034719714814e12

# %%
function reconst(T)
    nmom = length(T)
    S = (1/sqrt(T[1])) * T * (1/sqrt(T[1]))
    println(S)

    As = Dict{Int,ComplexF64}()
    Bs = Dict{Int,ComplexF64}()
    Cs = Dict{Tuple{Int,Int},ComplexF64}()

    # Initial values
    As[0] = S[2]
    Bs[0] = 0.0
    Cs[0,0] = 1.0

    function get_S(i)
        i <= nmom-1 ? S[i+1] : 0.0
    end
    
    function get_Cs(n, j)::ComplexF64
        if j < 0 || j > n || n < 0
            return 0.0
        end
        return Cs[(n, j)]
    end

    for n in 0:nmom
        #println("n = $n")
        # Update B[n+1]
        bfirst = sum(conj(Cs[n,l]) * get_S(j+l+1) * get_Cs(n, j-1) for j in 0:(n+1), l in 0:n)
        Bs[n+1] = sqrt(bfirst  - As[n]^2  - conj(Bs[n]^2))

        # C(n+1, j) for j = 0, ..., n+1 (otherwise 0)
        for j in 0:(n+1)
            Cs[(n+1, j)] = (get_Cs(n, j-1) - get_Cs(n, j) * As[n] - get_Cs(n-1, j) * conj(Bs[n])) / Bs[n+1]
        end

        # Update A[n+1]
        As[n+1] = sum(conj(get_Cs(n+1, l) * get_S(j+l+1) * get_Cs(n+1, j)) for j in 0:(n+1), l in 0:(n+1))

        if length(As) >= (nmom + 1) ÷ 2
            break
        end
    end
    return  As, Bs
end

As, Bs = reconst(Tp)
# Out:
# [1.0, 3.3599295566422986, 17.336666666666606, 93.3338652699821, 518.6667666666816, 2966.666689345114, 17426.666671775543, 104933.33333452676, 646653.3333332755, 4.0727333333286387e6, 2.618354666660372e7, 1.7164506666583955e8, 1.1462443466558018e9, 7.790962533190613e9, 5.385598917145834e10, 3.7835342130869855e11, 2.699606943942964e12]
# (Dict{Int64, ComplexF64}(0 => 3.3599295566422986 + 0.0im, 4 => 4.63202913623536 + 0.0im, 5 => 3.879411442845594 + 0.0im, 6 => 4.9380392271559685 + 0.0im, 2 => 5.1008720358059065 + 0.0im, 7 => 5.745074605569243 + 0.0im, 8 => -1.4686214407158697e8 + 0.0im, 3 => 5.291378452136996 + 0.0im, 1 => 2.4414188072781293 + 0.0im), Dict{Int64, ComplexF64}(0 => 0.0 + 0.0im, 4 => 1.8355986570484089 + 0.0im, 5 => 2.5811267046350435 + 0.0im, 6 => 2.685279466161692 + 0.0im, 2 => 1.5523288662680548 + 0.0im, 7 => 2.3116086914807528 + 0.0im, 8 => 2.2886662362976886 + 0.0im, 3 => 1.4200079207878726 + 0.0im, 1 => 2.4591746666449077 + 0.0im))

# %%
nc = length(As)
htri = zeros(ComplexF64, nc, nc)
for i in 1:nc
    htri[i, i] = As[i-1]
end
for i in 1:(nc-1)
    htri[i, i+1] = Bs[i]
    htri[i+1, i] = conj(Bs[i])
end

htri
# Out:
# 9×9 Matrix{ComplexF64}:
#  3.35993+0.0im  2.45917+0.0im  …      0.0+0.0im         0.0+0.0im
#  2.45917-0.0im  2.44142+0.0im         0.0+0.0im         0.0+0.0im
#      0.0+0.0im  1.55233-0.0im         0.0+0.0im         0.0+0.0im
#      0.0+0.0im      0.0+0.0im         0.0+0.0im         0.0+0.0im
#      0.0+0.0im      0.0+0.0im         0.0+0.0im         0.0+0.0im
#      0.0+0.0im      0.0+0.0im  …      0.0+0.0im         0.0+0.0im
#      0.0+0.0im      0.0+0.0im     2.31161+0.0im         0.0+0.0im
#      0.0+0.0im      0.0+0.0im     5.74507+0.0im     2.28867+0.0im
#      0.0+0.0im      0.0+0.0im     2.28867-0.0im  -1.46862e8+0.0im

# %%
e = eigen(Hermitian(htri))
# Out:
# Eigen{ComplexF64, Float64, Matrix{ComplexF64}, Vector{Float64}}
# values:
# 9-element Vector{Float64}:
#  -1.4686214407158697e8
#   0.04958028720743535
#   0.21712701737146922
#   2.834592232576341
#   4.085565296985314
#   5.2434668421923405
#   6.392460091327571
#   7.596169727763843
#   8.969191803911265
# vectors:
# 9×9 Matrix{ComplexF64}:
#     1.686e-63+0.0im   -0.521206-0.0im  …     0.107313-0.0im   0.0124863-0.0im
#  -1.00688e-55-0.0im    0.701607+0.0im        0.184861-0.0im   0.0284806-0.0im
#   9.52587e-48+0.0im   -0.255354-0.0im        0.443856-0.0im   0.0999845-0.0im
#  -9.85199e-40-0.0im    0.141368+0.0im        0.577875+0.0im    0.241239-0.0im
#   7.88236e-32+0.0im   -0.206156-0.0im         0.38222-0.0im       0.406-0.0im
#  -4.48494e-24-0.0im    0.265467+0.0im  …    0.0279751-0.0im    0.510656-0.0im
#   2.45288e-16+0.0im   -0.180457-0.0im       -0.328674-0.0im    0.577665+0.0im
#   -1.55838e-8-0.0im   0.0732415+0.0im       -0.410441-0.0im    0.414171-0.0im
#           1.0+0.0im  1.14138e-9-0.0im     -6.39622e-9-0.0im  6.45434e-9-0.0im

# %%
weight = real.(conj.(e.vectors[1, :]) .* e.vectors[1, :])
# Out:
# 9-element Vector{Float64}:
#  2.842604052894368e-126
#  0.2716554473540043
#  0.06203953936604733
#  0.034553381945641386
#  0.20741562973487576
#  0.29519696377593935
#  0.1174669588221194
#  0.01151617221133248
#  0.00015590679004034375

# %%
sum(weight)
# Out:
# 1.0000000000000004

# %%
δ = 0.7
#p = 0.25
gaussian(x, μ) = exp(-0.5 * ((x-μ)/δ)^2)/(sqrt(2π) * δ)

cp = quadgk(x -> aomega(x), 0, wmax)[1]
aomega_reconst = zeros(Float64, length(omegas))
for ie in eachindex(e.values)
    aomega_reconst .+= cp * gaussian.(omegas, e.values[ie]) * weight[ie]
end

p = plot(xlim=(-wmax, wmax))
plot!(p, omegas, (aomega_reconst), xlim=(-wmax, wmax), marker=:x)
plot!(p, omegas, aomega.(omegas))

# %% [markdown]
# # hole

# %%
Th = Float64[]
for mom in 0:(nmom-1)
    push!(Th, quadgk(x -> (x^mom) * aomega(x), -wmax, 0)[1])
end
Th
# Out:
# 17-element Vector{Float64}:
#       0.4999999999999998
#      -1.6799647783211484
#       8.668333333333297
#     -46.66693263499102
#     259.33338333334063
#   -1483.3333446725562
#    8713.333335887768
#  -52466.66666726336
#  323326.6666666376
#      -2.0363666666643182e6
#       1.3091773333301853e7
#      -8.582253333291975e7
#       5.731221733279006e8
#      -3.8954812665953045e9
#       2.6927994585729156e10
#      -1.8917671065434918e11
#       1.3498034719714817e12

# %%
Ash, Bsh = reconst(Th)
# Out:
# [1.0, -3.3599295566422986, 17.336666666666602, -93.3338652699821, 518.6667666666815, -2966.666689345114, 17426.666671775543, -104933.33333452676, 646653.3333332755, -4.0727333333286378e6, 2.618354666660372e7, -1.7164506666583955e8, 1.1462443466558018e9, -7.790962533190613e9, 5.3855989171458336e10, -3.7835342130869855e11, 2.699606943942965e12]
# (Dict{Int64, ComplexF64}(0 => -3.3599295566422986 + 0.0im, 4 => -4.632029136286292 + 0.0im, 5 => -3.879411441652337 + 0.0im, 6 => -4.938039192464203 + 0.0im, 2 => -5.10087203580602 + 0.0im, 7 => -5.7450741566717625 + 0.0im, 8 => 1.4686205616867542e8 + 0.0im, 3 => -5.291378452140179 + 0.0im, 1 => -2.4414188072781347 + 0.0im), Dict{Int64, ComplexF64}(0 => 0.0 + 0.0im, 4 => 1.8355986570435074 + 0.0im, 5 => 2.5811267047500897 + 0.0im, 6 => 2.685279469032243 + 0.0im, 2 => 1.5523288662680481 + 0.0im, 7 => 2.311608777161344 + 0.0im, 8 => 2.2886668338554506 + 0.0im, 3 => 1.4200079207874707 + 0.0im, 1 => 2.459174666644907 + 0.0im))

# %%
nch = length(Ash)
htrih = zeros(ComplexF64, nc, nc)
for i in 1:nch
    htrih[i, i] = Ash[i-1]
end
for i in 1:(nch-1)
    htrih[i, i+1] = Bsh[i]
    htrih[i+1, i] = conj(Bsh[i])
end

htrih
# Out:
# 9×9 Matrix{ComplexF64}:
#  -3.35993+0.0im   2.45917+0.0im  …       0.0+0.0im        0.0+0.0im
#   2.45917-0.0im  -2.44142+0.0im          0.0+0.0im        0.0+0.0im
#       0.0+0.0im   1.55233-0.0im          0.0+0.0im        0.0+0.0im
#       0.0+0.0im       0.0+0.0im          0.0+0.0im        0.0+0.0im
#       0.0+0.0im       0.0+0.0im          0.0+0.0im        0.0+0.0im
#       0.0+0.0im       0.0+0.0im  …       0.0+0.0im        0.0+0.0im
#       0.0+0.0im       0.0+0.0im      2.31161+0.0im        0.0+0.0im
#       0.0+0.0im       0.0+0.0im     -5.74507+0.0im    2.28867+0.0im
#       0.0+0.0im       0.0+0.0im      2.28867-0.0im  1.46862e8+0.0im

# %%
eh = eigen(Hermitian(htrih))
# Out:
# Eigen{ComplexF64, Float64, Matrix{ComplexF64}, Vector{Float64}}
# values:
# 9-element Vector{Float64}:
#  -8.969191757768186
#  -7.5961696714658435
#  -6.392460024543643
#  -5.243466764153412
#  -4.085565206964347
#  -2.8345921309003685
#  -0.2171269777759015
#  -0.04958028103563805
#   1.4686205616867542e8
# vectors:
# 9×9 Matrix{ComplexF64}:
#   0.0124863+0.0im   -0.107313-0.0im    -0.342735-0.0im  …  1.68601e-63-0.0im
#  -0.0284806-0.0im    0.184861+0.0im     0.422643+0.0im     1.00689e-55-0.0im
#   0.0999845+0.0im   -0.443856-0.0im    -0.532771-0.0im     9.52591e-48-0.0im
#   -0.241239-0.0im    0.577875+0.0im     0.022563-0.0im     9.85202e-40-0.0im
#       0.406+0.0im    -0.38222-0.0im     0.398614+0.0im     7.88238e-32-0.0im
#   -0.510656-0.0im   0.0279751+0.0im    -0.287917-0.0im  …  4.48495e-24-0.0im
#    0.577665+0.0im    0.328674-0.0im    -0.113703-0.0im     2.45289e-16-0.0im
#   -0.414171-0.0im   -0.410441-0.0im     0.405998+0.0im      1.55838e-8-0.0im
#  6.45435e-9+0.0im  6.39623e-9+0.0im  -6.32699e-9-0.0im             1.0+0.0im

# %%
weighth = real.(conj.(eh.vectors[1, :]) .* eh.vectors[1, :])
# Out:
# 9-element Vector{Float64}:
#  0.00015590681964666316
#  0.011516173987690505
#  0.11746697083972568
#  0.29519697239633497
#  0.20741561479259094
#  0.03455337459889358
#  0.06203956296479591
#  0.2716554236003221
#  2.8426329770717683e-126

# %%
sum(weighth)
# Out:
# 1.0000000000000004

# %%
#hole
δh = 0.7
gaussianh(x, μh) = exp(-0.5 * ((x-μh)/δh)^2)/(sqrt(2π) * δh)

#hole
ch = quadgk(x -> aomega(x), -wmax, 0)[1]
aomega_reconsth = zeros(Float64, length(omegas))
for ieh in eachindex(eh.values)
    aomega_reconsth .+= ch * gaussianh.(omegas, eh.values[ieh]) * weighth[ieh]
end


p = plot(xlim=(-wmax, wmax))
plot!(p, omegas, aomega.(omegas))
plot!(p, omegas, (aomega_reconsth), xlim=(-wmax, wmax), marker=:x)

# %% [markdown]
# # whole picture

# %%
aomega_reconst_all = (aomega_reconst + aomega_reconsth)
#println(aomega_reconst_all)
p = plot(xlim=(-wmax, wmax))
plot!(p, omegas, aomega.(omegas))
plot!(p, omegas, (aomega_reconst_all), xlim=(-wmax, wmax), marker=:x)
#plot!(p, omegas, (aomega_reconsth),  xlim=(-wmax, wmax), maker=:x)

# %%
savefig("nmom=$(nmom)")
